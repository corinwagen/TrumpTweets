# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('white')

from scipy.stats import ttest_ind

# %%
df = pd.read_csv('au_ttest_results.csv', sep=";")
df.columns = ["model_name", "t", "p", "l", "r_5", "r", "r_95"]
df.describe()
# Out:
#                 t             p           l         r_5           r  \
# count  499.000000  4.990000e+02  499.000000  499.000000  499.000000
# mean    14.514201  1.155051e-02  170.949786  169.578929  184.518185
# std      6.410998  7.868068e-02    6.278767    2.910982    2.758868
# min     -2.704564  5.421296e-58  154.082024  161.971354  177.224729
# 25%     10.361522  1.483742e-34  166.722691  167.638404  182.630053
# 50%     14.699468  1.245881e-26  170.738338  169.647805  184.364080
# 75%     18.868761  1.782001e-17  174.918976  171.533839  186.294786
# max     35.385042  8.634313e-01  190.642477  179.561485  195.016552
#
#              r_95
# count  499.000000
# mean   200.406687
# std      3.931212
# min    190.193036
# 25%    197.722656
# 50%    200.107948
# 75%    202.954220
# max    211.550259

# %%
fig = plt.figure(figsize=(10,7))
sns.distplot(df['l'], ax=fig.gca(), label='Model Loss')
sns.distplot(df['r'], ax=fig.gca(), label='Y-Randomized Loss')

plt.title('Model Performance Against Y-Randomized Control')
plt.xlabel('Loss')
plt.ylabel('Abundance')

plt.legend(loc='best')
plt.show()

# %%
ttest_ind(df['l'], df['r'])
# Out:
# Ttest_indResult(statistic=-44.1948572419929, pvalue=5.169822509794251e-237)
