# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('white')

from scipy.stats import ttest_ind

# %%
df = pd.read_csv('china_ttest_results.csv', sep=";")
df.columns = ["model_name", "t", "p", "l", "r_5", "r", "r_95"]
df.describe()
# Out:
#                 t             p           l         r_5           r  \
# count  499.000000  4.990000e+02  499.000000  499.000000  499.000000
# mean    22.902366  7.833012e-03    0.165964    0.177653    0.204771
# std      8.505430  6.602048e-02    0.027961    0.023270    0.026472
# min     -8.206903  8.815772e-67    0.098417    0.133956    0.156174
# 25%     17.974747  1.263794e-49    0.147045    0.162477    0.187294
# 50%     23.744890  1.154164e-42    0.160591    0.172724    0.200353
# 75%     28.580160  6.114485e-33    0.182641    0.187724    0.216221
# max     43.976760  8.157985e-01    0.275770    0.301898    0.337805
#
#              r_95
# count  499.000000
# mean     0.233589
# std      0.030493
# min      0.177565
# 25%      0.213524
# 50%      0.228557
# 75%      0.248149
# max      0.382263

# %%
fig = plt.figure(figsize=(10,7))
sns.distplot(df['l'], ax=fig.gca(), label='Model Loss')
sns.distplot(df['r'], ax=fig.gca(), label='Y-Randomized Loss')

plt.title('Model Performance Against Y-Randomized Control')
plt.xlabel('Loss')
plt.ylabel('Abundance')

plt.legend(loc='best')
plt.show()

# %%
ttest_ind(df['l'], df['r'])
# Out:
# Ttest_indResult(statistic=-22.513655548139923, pvalue=4.6229034722579803e-91)
