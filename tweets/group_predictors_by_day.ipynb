# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestRegressor

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set_style('white')

# %%
predictors = pd.read_csv('../tweets/cleaned_tweets_text')
columns = predictors.columns.values

predictors['clean_text'] = predictors['clean_text'].astype(str)

pred_by_day = predictors.groupby([predictors.year.values,predictors.month.values, predictors.day.values]
).agg(
        {
            'clean_text': sum,
            'year':'first',
            'month':'first',
            'day':'first',
        }
    )

pred_by_day['Date'] = [f"{int(a[0]):d}-{int(a[1]):02d}-{int(a[2]):02d}" for a in zip(pred_by_day['year'],pred_by_day["month"],pred_by_day["day"])]
pred_by_day.head(10)
# Out:
#                                                         clean_text    year  \
# 2017.0 1.0 20.0  TO ALL AMERICANS🇺🇸So to all Americans in every...  2017.0
#            21.0  Retweet WhiteHouse: "Do not allow anyone to te...  2017.0
#            22.0  Peaceful protests are a hallmark of our democr...  2017.0
#            23.0  Busy week planned with a heavy focus on jobs a...  2017.0
#            24.0  Signing orders to move forward with the constr...  2017.0
#            25.0  I will be interviewed by DavidMuir tonight at ...  2017.0
#            26.0  Miami-Dade Mayor drops sanctuary policy. Right...  2017.0
#            27.0  I promise that our administration will ALWAYS ...  2017.0
#            28.0  I will be interviewed by TheBrodyFile on CBNNe...  2017.0
#            29.0  I will be interviewed by TheBrodyFile on CBNNe...  2017.0
#
#                  month   day        Date
# 2017.0 1.0 20.0    1.0  20.0  2017-01-20
#            21.0    1.0  21.0  2017-01-21
#            22.0    1.0  22.0  2017-01-22
#            23.0    1.0  23.0  2017-01-23
#            24.0    1.0  24.0  2017-01-24
#            25.0    1.0  25.0  2017-01-25
#            26.0    1.0  26.0  2017-01-26
#            27.0    1.0  27.0  2017-01-27
#            28.0    1.0  28.0  2017-01-28
#            29.0    1.0  29.0  2017-01-29

# %%
pred_by_day.to_csv('../tweets/cleaned_tweet_text_by_day')
